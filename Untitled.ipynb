# %%
# !pip install langchain langchain-community sentence-transformers chromadb pdfminer.six faiss-cpu transformers torch
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list | findstr langchain
# Out:
# langchain                                0.3.25
# langchain-community                      0.3.23
# langchain-core                           0.3.59
# langchain-text-splitters                 0.3.8
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-text-splitters
# Out:
# Found existing installation: langchain 0.3.25
# Uninstalling langchain-0.3.25:
#   Successfully uninstalled langchain-0.3.25
# Found existing installation: langchain-core 0.3.59
# Uninstalling langchain-core-0.3.59:
#   Successfully uninstalled langchain-core-0.3.59
# Found existing installation: langchain-community 0.3.23
# Uninstalling langchain-community-0.3.23:
#   Successfully uninstalled langchain-community-0.3.23
# Found existing installation: langchain-text-splitters 0.3.8
# Uninstalling langchain-text-splitters-0.3.8:
#   Successfully uninstalled langchain-text-splitters-0.3.8

# %%
# !pip install langchain==0.0.346 langchain-community==0.0.14
# Out:
# ...
#                                               0.0/2.0 MB ? eta -:--:--
#                                               0.0/2.0 MB 660.6 kB/s eta 0:00:03
#                                               0.0/2.0 MB 660.6 kB/s eta 0:00:03
#                                               0.0/2.0 MB 660.6 kB/s eta 0:00:03
#                                               0.0/2.0 MB 660.6 kB/s eta 0:00:03
#      -                                        0.1/2.0 MB 201.8 kB/s eta 0:00:10
#      -                                        0.1/2.0 MB 309.1 kB/s eta 0:00:07
#      --                                       0.1/2.0 MB 328.0 kB/s eta 0:00:06
#      --                                       0.1/2.0 MB 328.0 kB/s eta 0:00:06
#      --                                       0.1/2.0 MB 288.8 kB/s eta 0:00:07
#      ---                                      0.2/2.0 MB 374.9 kB/s eta 0:00:05
#      ----                                     0.2/2.0 MB 444.3 kB/s eta 0:00:04
# ...

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-text-splitters
# Out:
# WARNING: Skipping langchain as it is not installed.
# WARNING: Skipping langchain-core as it is not installed.
# WARNING: Skipping langchain-community as it is not installed.
# WARNING: Skipping langchain-text-splitters as it is not installed.

# %%
# !pip install langchain==0.0.340 langchain-community==0.0.12
# Out:
# ...
#                                               0.0/2.0 MB ? eta -:--:--
#                                               0.0/2.0 MB 1.3 MB/s eta 0:00:02
#                                               0.0/2.0 MB 1.3 MB/s eta 0:00:02
#                                               0.0/2.0 MB 1.3 MB/s eta 0:00:02
#                                               0.0/2.0 MB 1.3 MB/s eta 0:00:02
#      -                                        0.1/2.0 MB 187.0 kB/s eta 0:00:11
#      -                                        0.1/2.0 MB 308.0 kB/s eta 0:00:07
#      --                                       0.1/2.0 MB 326.8 kB/s eta 0:00:06
#      --                                       0.1/2.0 MB 326.8 kB/s eta 0:00:06
#      --                                       0.1/2.0 MB 326.8 kB/s eta 0:00:06
#      ---                                      0.2/2.0 MB 315.8 kB/s eta 0:00:06
#      ----                                     0.2/2.0 MB 430.1 kB/s eta 0:00:05
# ...

# %%
# !pip install sentence-transformers chromadb pdfminer.six faiss-cpu transformers torch
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import sys
import logging
from pathlib import Path

# LangChain imports
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain_community.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate

# Transformers for running local models
import torch
from transformers import (
    AutoTokenizer, 
    AutoModelForCausalLM,
    pipeline
)

# Set up logging
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

print(f"Python version: {sys.version}")
print("All libraries imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 from pathlib import Path
#       6 # LangChain imports
# ----> 7 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       8 from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
#       9 from langchain_community.embeddings import HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'langchain'

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-text-splitters
# !pip install --upgrade pip
# Out:
# Found existing installation: langchain 0.0.340
# Uninstalling langchain-0.0.340:
#   Successfully uninstalled langchain-0.0.340
# Found existing installation: langchain-core 0.1.23
# Uninstalling langchain-core-0.1.23:
#   Successfully uninstalled langchain-core-0.1.23
# Found existing installation: langchain-community 0.0.12
# Uninstalling langchain-community-0.0.12:
#   Successfully uninstalled langchain-community-0.0.12
# WARNING: Skipping langchain-text-splitters as it is not installed.
# ...
#   Using cached pip-25.1.1-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\Msi\Desktop\CTSE_Lecture_Notes_Chatbot\CTSE_Lecture_Notes_Chatbot\venv\Scripts\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain==0.1.0 langchain-community==0.0.20 langchain-core==0.1.0
# !pip install sentence-transformers chromadb pdfminer.six faiss-cpu transformers torch
# Out:
# ...
#                                               0.0/798.0 kB ? eta -:--:--
#      -                                       30.7/798.0 kB 1.3 MB/s eta 0:00:01
#      -                                       30.7/798.0 kB 1.3 MB/s eta 0:00:01
#      -                                       30.7/798.0 kB 1.3 MB/s eta 0:00:01
#      -                                       30.7/798.0 kB 1.3 MB/s eta 0:00:01
#      --                                    51.2/798.0 kB 187.0 kB/s eta 0:00:04
#      ----                                  92.2/798.0 kB 308.0 kB/s eta 0:00:03
#      -----                                112.6/798.0 kB 363.1 kB/s eta 0:00:02
#      -----                                112.6/798.0 kB 363.1 kB/s eta 0:00:02
#      -----                                122.9/798.0 kB 288.1 kB/s eta 0:00:03
#      -------                              174.1/798.0 kB 361.7 kB/s eta 0:00:02
#      ---------                            204.8/798.0 kB 401.2 kB/s eta 0:00:02
# ...

# %%
# !pip uninstall -y langchain langchain-core langchain-community
# !python -m pip install --upgrade pip
# Out:
# WARNING: Skipping langchain as it is not installed.
# WARNING: Skipping langchain-core as it is not installed.
# WARNING: Skipping langchain-community as it is not installed.
# ...
#   Using cached pip-25.1.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# ...

# %%
# !pip install langchain==0.0.348 langchain-community==0.0.16
# !pip install sentence-transformers chromadb pdfminer.six faiss-cpu transformers torch
# Out:
# ...
# INFO: pip is looking at multiple versions of langchain-community to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     langchain 0.0.348 depends on langchain-core<0.1 and >=0.0.12
#     langchain-community 0.0.16 depends on langchain-core<0.2 and >=0.1.16
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
# ERROR: Cannot install langchain-community==0.0.16 and langchain==0.0.348 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# ...
